# %%
from environment import EvaluationEnvironment
import numpy as np
from game import GlobalFeatureImportance, LocalFeatureImportance, UnsupervisedFeatureImportance
from plot import plot
import util

# %%
from algorithms.CMCS import *
from algorithms.GapE import GapE
from algorithms.SAR import SAR
from algorithms.ApproShapley import ApproShapley
from algorithms.BUS import BUS
from algorithms.SVARM import SVARM, StratSVARM
from algorithms.KernelSHAP import KernelSHAP
from algorithms.shap_k import SHAP_K
from algorithms.compshap import compSHAP
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
k=3
budget=1500
num_experiments=500
step_interval=50
env = EvaluationEnvironment()
results = []

# %%
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})

# %%
filepath_global = "datasets/global/Bank marketing classification random forest.csv"
filepath_unsupervised = "datasets/unsupervised/vf_BigFive.csv"
directory_local = "datasets/local/image_classification"
# game = GlobalFeatureImportance(filepath=filepath_global, use_cached=True)
game = LocalFeatureImportance(directory=directory_local, num_players=n)
# game = UnsupervisedFeatureImportance(filepath=filepath_unsupervised, num_players=n)
# Out:
# [0.000 -0.006 0.000 ... 0.011 0.006 0.008] 16
# [-0.000 -0.000 0.001 0.000 -0.000 -0.010 -0.001 0.000 0.001 0.004 0.002
#  0.004 -0.000 0.002 0.001 0.005] 0.008106116433308063

# %%
# results += [("SAR", *env.evaluate_fixed_k(game, SAR(), k, budget, step_interval, num_experiments))]

# %%
results += [("compSHAP", *env.evaluate_fixed_k(game, compSHAP(), k, budget, step_interval, num_experiments))]
# Out:
# d:\top-k-shapley\algorithms\compshap.py:37: RuntimeWarning: invalid value encountered in divide
#   phi_approx = -diff / count

# %%
results += [("CMCS", *env.evaluate_fixed_k(game, CMCS(), k, budget, step_interval, num_experiments))]

# %%
results += [("GapE", *env.evaluate_fixed_k(game, GapE(), k, budget, step_interval, num_experiments))]
results += [("BUS", *env.evaluate_fixed_k(game, BUS(), k, budget, step_interval, num_experiments))]

# %%
results += [("KernelSHAP", *env.evaluate_fixed_k(game, KernelSHAP(), k, budget, step_interval, 100))]

# %%
results += [("CMCS@K(T_min=30, delta=0.01)", *env.evaluate_fixed_k(game, CMCS_at_K(t_min=30, delta=0.01), k, budget, step_interval, num_experiments))]

# %%
results += [("SHAP@K(T_min=30, delta=0.01)", *env.evaluate_fixed_k(game, SHAP_K(t_min=30, delta=0.01), k, budget, step_interval, num_experiments))]

# %%
results += [("Greedy CMCS", *env.evaluate_fixed_k(game, Greedy_CMCS(t_min=30, delta=0.01), k, budget, step_interval, num_experiments))]

# %%
results += [("StratSVARM", *env.evaluate_fixed_k(game, StratSVARM(), k, budget, step_interval, num_experiments))]

# %%
# results += [("ApproShapley", *env.evaluate_fixed_k(game, ApproShapley(), k, budget, step_interval, num_experiments))]

# %%
# results += [("BUS", *env.evaluate_fixed_k(game, BUS(), k, budget, step_interval, num_experiments))]

# %%
labels = {
    "mse": ("budget", "mse"),
    "ratio": ("budget", "ratio"),
    "numeric": ("budget", "numeric"),
    "epsilon": ("budget", "epsilon"),
}
measures = ["ratio", "epsilon", "mse"]
plot(results, labels, measures=measures, save=True, filepath=f"results/{game.__class__.__name__}({game.name})_k={k}_budget={budget}_r={num_experiments}.pdf")
